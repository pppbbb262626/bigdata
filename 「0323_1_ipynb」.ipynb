# %% [markdown]
# <a href="https://colab.research.google.com/github/pppbbb262626/bigdata/blob/main/%E3%80%8C0323_1_ipynb%E3%80%8D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("ggplot2")#安裝
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("SportsAnalytics")#安裝
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library("SportsAnalytics")#載入套件
library("ggplot2")

# %%
NBA1516 <- fetch_NBAPlayerStatistics("15-16")#讀入資料

# %%
qplot(ThreesAttempted,TotalPoints,data = NBA1516)
# Out:
# plot without title

# %%
qplot(ThreesAttempted,TotalPoints,data = NBA1516,color=Position)
# Out:
# plot without title

# %%
qplot(FieldGoalsAttempted,TotalPoints,data = NBA1516)
# Out:
# plot without title

# %%
qplot(FieldGoalsAttempted,TotalPoints,data = NBA1516,color=Position)
# Out:
# plot without title

# %%
qplot(FieldGoalsAttempted,TotalPoints,data = NBA1516,color=Team)
# Out:
# plot without title

# %%
qplot(ThreesAttempted,TotalPoints,data = NBA1516,color=Team)
# Out:
# plot without title

# %%
qplot(FieldGoalsAttempted, TotalPoints, data = NBA1516,
 geom = c("point", "smooth"))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
#畫TotalPoints的直⽅圖/ fill = Position 並⽤守備位置Position著⾊
qplot(TotalPoints, data = NBA1516, fill = Position)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
#facets = . ~ Position 用守備位置Position分群畫圖(直向)
qplot(FieldGoalsAttempted,TotalPoints,
  data = NBA1516,
  facets = Position ~ .)
# Out:
# plot without title

# %%
#facets = . ~ Position 用守備位置Position分群畫圖(橫向)
qplot(FieldGoalsAttempted,TotalPoints,
  data = NBA1516,
  facets = . ~ Position )
# Out:
# plot without title

# %%
#facets = . ~ Position 用守備位置Position分群畫圖(直向)
#binwidth = 10 每10分一組
qplot(TotalPoints,
  data = NBA1516,
  facets = Position ~ . ,binwidth = 10 )
# Out:
# plot without title

# %%
#facets = . ~ Position 用守備位置Position分群畫圖(直向)
#binwidth = 100 每100分一組
qplot(TotalPoints,
  data = NBA1516,
  facets = Position ~ . ,binwidth = 100 )
# Out:
# plot without title
